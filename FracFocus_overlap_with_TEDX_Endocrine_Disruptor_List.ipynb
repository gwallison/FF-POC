# %% [markdown]
# # Introduction
# The TEDX Endocrine Disruptor Chemical list has ~1400 compounds that are 'potential' endocrine disruptors and about 10% of those are labeled as being used in Unconventional Oil/Gas operations.  Given that FracFocus actually lists a lot (though not all) chemicals used in a fracking operation, we should be able to compare the lists.  Both lists use CAS numbers so the we can use those to find the intersection of two lists.

# %% [markdown]
# Load in the CAS Numbers and names from the TEDX list
# ---

# %% [markdown]
# The [TEDX website](https://endocrinedisruption.org/interactive-tools/tedx-list-of-potential-endocrine-disruptors/search-the-tedx-list#sname=&searchfor=any&sortby=chemname&action=search&searchcats=all&sortby=chemname) allows us to download the entire curated list.  The code below uses a trimmed version that makes it easier for computer reading.

# %%
# Code preamble
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


results_dir = './out/'       # for local use
#results_dir = '../results/' # for CodeOcean
data_dir = './sources/'      # for local use
#data_dir = '../data/'         # for CodeOcean

# %%
TEDXfn = data_dir+'TEDX_EDC_trimmed.xls'
tx = pd.read_excel(TEDXfn, encoding = "ISO-8859-1")
tx = tx.groupby('CAS_Num',as_index=False)['TEDX_Chem_Name'].first()
# print sample and length of the TEDX list
print(f'Number of chemicals in trimmed TEDX list: {len(tx)}')
tx.head()  # show just the first five chemicals in the list
# Out:
# Number of chemicals in trimmed TEDX list: 1354
#     CAS_Num         TEDX_Chem_Name
# 0  100-01-6         p-nitroaniline
# 1  100-02-7          4-nitrophenol
# 2  100-09-4  4-methoxybenzoic acid
# 3  100-41-4           ethylbenzene
# 4  100-42-5                styrene

# %% [markdown]
# ### Make a list of the CAS numbers from the TEDX list

# %%
tx_cas = list(tx.CAS_Num.unique())

# %% [markdown]
# ## Load the filtered FracFocus data

# %%
# pull data from the results directory where it is stored as a .csv file

df = pd.read_csv(results_dir+'filtered_df.csv')
df.date = pd.to_datetime(df.date)  # put date back into datetime format
print(f'Total number of chemical records in filtered data set: {len(df)}')
# Out:
# Total number of chemical records in filtered data set: 3014015

# %% [markdown]
# ### Keep only those records that are in the TEDX list

# %%
df = df[df.bgCAS.isin(tx_cas)]
print(f'Total number of chemical records with TEDX overlap: {len(df)}')
print(f'  -- number records that have calculated mass:      {len(df[df.bgMass>0])}')
print(f'  -- with a total unique chemicals: {len(df.bgCAS.unique())}')
# Out:
# Total number of chemical records with TEDX overlap: 544311
#   -- number records that have calculated mass:      475409
#   -- with a total unique chemicals: 115

# %%
df = pd.merge(df,tx,left_on='bgCAS',right_on='CAS_Num',how='left',validate='m:1')
df.drop('CAS_Num',axis=1,inplace =True)

# %% [markdown]
# ### Compute the number of events and some simple statistics

# %%
gb1 = df.groupby(['UploadKey','bgCAS'],as_index=False)['CASNumber'].count()
gb2 = gb1.groupby('bgCAS',as_index=False)['UploadKey'].count()
gb3a = df.groupby('bgCAS',as_index=False)['bgMass'].mean()
gb3a.columns = ['bgCAS','mean_mass_lbs']
gb3b = df.groupby('bgCAS',as_index=False)['bgMass'].sum()
gb3b.columns = ['bgCAS','total_mass_lbs']
gb3c = df.groupby('bgCAS',as_index=False)['bgMass'].max()
gb3c.columns = ['bgCAS','max_mass_lbs']
gb4 = df.groupby('bgCAS',as_index=False)['bgIngredientName','TEDX_Chem_Name'].first()
mg = pd.merge(gb2,gb3a)
mg = pd.merge(mg,gb3b)
mg = pd.merge(mg,gb3c)
mg = pd.merge(mg,gb4).sort_values(by='UploadKey',ascending=False)

# save the list to the results directory
mg.to_csv(results_dir+'TEDX_Chem_in_FF.csv')
# mg.to_excel(results_dir+'TEDX_Chem_in_FF.xlsx')

# %% [markdown]
# ### Sorted to show most frequent
# See the CSV file for the full list.

# %%
mg.head(30)
# Out:
#           bgCAS  UploadKey  mean_mass_lbs  total_mass_lbs  max_mass_lbs  \
# 71      67-56-1      66203    3977.628139    4.189158e+08  2.771049e+06
# 14     107-21-1      41667    2902.347082    1.343932e+08  1.316196e+06
# 66      64-17-5      29981    4224.847152    1.220432e+08  3.707897e+05
# 13     107-19-7      27576     126.999639    3.154671e+06  5.453396e+04
# 21     111-30-8      27312    3854.642151    9.956155e+07  9.902205e+05
# 35   12125-02-9      25648    3035.674201    7.715470e+07  4.490093e+05
# 25     111-76-2      20384    2132.437441    4.898209e+07  4.302192e+05
# 76    7173-51-5      14131    1441.191628    1.956274e+07  2.477550e+05
# 96    7758-19-2      14013    5239.430068    6.717997e+07  2.523339e+06
# 110   9005-65-6      13253    1643.224571    1.863745e+07  1.181340e+05
# 112     91-20-3      13094     709.610184    8.949604e+06  9.590335e+04
# 7    10222-01-2      11846    2286.377529    2.704327e+07  4.889942e+05
# 9      104-55-2      11115     170.168615    1.848031e+06  1.518647e+05
# 74      68-12-2      10105     327.099744    3.048897e+06  2.024871e+05
# 56      50-00-0       9852     515.987340    4.216133e+06  1.092017e+06
# 111   9016-45-9       9424    1491.908485    1.557702e+07  1.243543e+05
# 40    1303-96-4       8117    1981.690242    1.564148e+07  9.930551e+04
# 22     111-42-2       7472    5586.911276    4.600263e+07  1.912059e+05
# 60   55566-30-8       7320    4215.746574    2.991494e+07  5.178666e+04
# 63      57-55-6       6677    6016.021123    3.501324e+07  2.196925e+05
# 82    7447-40-7       6015   71998.203690    3.704308e+08  2.585980e+07
# 23     111-46-6       5698     159.340241    8.131133e+05  3.151759e+04
# 4    10043-35-3       5113    2880.147838    1.258913e+07  1.035060e+05
# 5    10049-04-4       4897    9063.889135    3.962732e+07  5.145341e+06
# 10     104-76-7       4751     733.774869    3.186784e+06  3.967747e+04
# 46   13463-67-7       4132   10419.385206    4.628291e+07  1.154219e+06
# 49     144-55-8       3987    1161.916254    4.271204e+06  4.565996e+04
# 54    3252-43-5       3281     677.930589    2.208698e+06  8.149870e+04
# 1      100-44-7       2910      17.627299    4.456181e+04  1.196144e+03
# 100   7786-30-3       2867    1997.302532    5.438655e+06  1.713428e+05
#
#                                       bgIngredientName  \
# 71                                            methanol
# 14                                      1,2-ethanediol
# 66                                             ethanol
# 13                                       2-propyn-1-ol
# 21                                         pentanedial
# 35                         ammonium chloride ((nh4)cl)
# 25                                  ethanol, 2-butoxy-
# 76   1-decanaminium, n-decyl-n,n-dimethyl-, chlorid...
# 96                    chlorous acid, sodium salt (1:1)
# 110  sorbitan, mono-(9z)-9-octadecenoate, poly(oxy-...
# 112                                        naphthalene
# 7                      acetamide, 2,2-dibromo-2-cyano-
# 9                                2-propenal, 3-phenyl-
# 74                            formamide, n,n-dimethyl-
# 56                                        formaldehyde
# 111  poly(oxy-1,2-ethanediyl), î±-(nonylphenyl)-ï‰-...
# 40                               borax (b4na2o7.10h2o)
# 22                             ethanol, 2,2'-iminobis-
# 60   phosphonium, tetrakis(hydroxymethyl)-, sulfate...
# 63                                     1,2-propanediol
# 82                            potassium chloride (kcl)
# 23                               ethanol, 2,2'-oxybis-
# 4                                   boric acid (h3bo3)
# 5                                chlorine oxide (clo2)
# 10                                 1-hexanol, 2-ethyl-
# 46                               titanium oxide (tio2)
# 49                     carbonic acid sodium salt (1:1)
# 54                          acetonitrile, 2,2-dibromo-
# 1                             benzene, (chloromethyl)-
# 100                         magnesium chloride (mgcl2)
#
#                                   TEDX_Chem_Name
# 71                                      methanol
# 14                               ethylene glycol
# 66                                       ethanol
# 13                             propargyl alcohol
# 21                                glutaraldehyde
# 35                             ammonium chloride
# 25               ethylene glycol monobutyl ether
# 76            didecyl dimethyl ammonium chloride
# 96                              sodium chlorite
# 110                               polysorbate 80
# 112                                  naphthalene
# 7             2,2-dibromo-3-nitrilopropionamide
# 9                               3-phenylpropenal
# 74                             dimethylformamide
# 56                                  formaldehyde
# 111        polyethylene glycol nonylphenyl ether
# 40                                         borax
# 22                                diethanolamine
# 60   tetrakis(hydroxymethyl) phosphonium sulfate
# 63                              propylene glycol
# 82                            potassium chloride
# 23                             diethylene glycol
# 4                                     boric acid
# 5                               chlorine dioxide
# 10                                2-ethylhexanol
# 46                titanium dioxide nanoparticles
# 49                            sodium bicarbonate
# 54                           dibromoacetonitrile
# 1                                benzyl chloride
# 100                           magnesium chloride

# %% [markdown]
# ### Sorted to show chemicals with largest mean mass

# %%
mg.sort_values(by='mean_mass_lbs',ascending=False).head(30)
# Out:
#           bgCAS  UploadKey  mean_mass_lbs  total_mass_lbs  max_mass_lbs  \
# 82    7447-40-7       6015   71998.203690    3.704308e+08  2.585980e+07
# 104   8002-05-9          3   60223.837508    6.022384e+04  6.022384e+04
# 89    7631-99-4        775   16228.031710    1.415084e+07  4.952183e+05
# 102   7789-38-0        642   12183.852028    6.749854e+06  1.510422e+06
# 46   13463-67-7       4132   10419.385206    4.628291e+07  1.154219e+06
# 5    10049-04-4       4897    9063.889135    3.962732e+07  5.145341e+06
# 77    7429-90-5          5    8324.926679    4.162463e+04  9.421821e+03
# 45    1344-09-8          3    8014.720972    2.404416e+04  9.045530e+03
# 70      65-85-0        270    6937.177972    1.789792e+06  2.662308e+05
# 57   51200-87-4       2150    6276.734446    1.316231e+07  4.335614e+05
# 63      57-55-6       6677    6016.021123    3.501324e+07  2.196925e+05
# 22     111-42-2       7472    5586.911276    4.600263e+07  1.912059e+05
# 96    7758-19-2      14013    5239.430068    6.717997e+07  2.523339e+06
# 103     80-05-7        133    4765.735068    5.099337e+05  1.889754e+04
# 109   9004-62-0        552    4507.602240    2.411567e+06  3.295388e+05
# 3    10025-91-9         70    4246.366200    2.547820e+05  1.042506e+04
# 66      64-17-5      29981    4224.847152    1.220432e+08  3.707897e+05
# 60   55566-30-8       7320    4215.746574    2.991494e+07  5.178666e+04
# 71      67-56-1      66203    3977.628139    4.189158e+08  2.771049e+06
# 21     111-30-8      27312    3854.642151    9.956155e+07  9.902205e+05
# 99    7783-20-2        761    3172.689569    2.090802e+06  4.589859e+04
# 35   12125-02-9      25648    3035.674201    7.715470e+07  4.490093e+05
# 14     107-21-1      41667    2902.347082    1.343932e+08  1.316196e+06
# 4    10043-35-3       5113    2880.147838    1.258913e+07  1.035060e+05
# 44    1330-43-4       1296    2816.560223    2.853176e+06  3.897924e+04
# 7    10222-01-2      11846    2286.377529    2.704327e+07  4.889942e+05
# 25     111-76-2      20384    2132.437441    4.898209e+07  4.302192e+05
# 72      67-64-1       1520    2123.126647    2.318454e+06  1.555752e+05
# 6      102-71-6       2189    2046.402312    4.166475e+06  2.738926e+05
# 100   7786-30-3       2867    1997.302532    5.438655e+06  1.713428e+05
#
#                                       bgIngredientName  \
# 82                            potassium chloride (kcl)
# 104                                          petroleum
# 89                       nitric acid sodium salt (1:1)
# 102                     bromic acid, sodium salt (1:1)
# 46                               titanium oxide (tio2)
# 5                                chlorine oxide (clo2)
# 77                                            aluminum
# 45                           silicic acid, sodium salt
# 70                                        benzoic acid
# 57                          oxazolidine, 4,4-dimethyl-
# 63                                     1,2-propanediol
# 22                             ethanol, 2,2'-iminobis-
# 96                    chlorous acid, sodium salt (1:1)
# 103              phenol, 4,4'-(1-methylethylidene)bis-
# 109                    cellulose, 2-hydroxyethyl ether
# 3                                  stibine, trichloro-
# 66                                             ethanol
# 60   phosphonium, tetrakis(hydroxymethyl)-, sulfate...
# 71                                            methanol
# 21                                         pentanedial
# 99                   sulfuric acid ammonium salt (1:2)
# 35                         ammonium chloride ((nh4)cl)
# 14                                      1,2-ethanediol
# 4                                   boric acid (h3bo3)
# 44                        boron sodium oxide (b4na2o7)
# 7                      acetamide, 2,2-dibromo-2-cyano-
# 25                                  ethanol, 2-butoxy-
# 72                                         2-propanone
# 6                       ethanol, 2,2',2''-nitrilotris-
# 100                         magnesium chloride (mgcl2)
#
#                                   TEDX_Chem_Name
# 82                            potassium chloride
# 104                 petroleum distillate naphtha
# 89                                sodium nitrate
# 102                               sodium bromate
# 46                titanium dioxide nanoparticles
# 5                               chlorine dioxide
# 77                                      aluminum
# 45                               sodium silicate
# 70                                  benzoic acid
# 57                   4,4’-dimethyl-1,3-oxazoline
# 63                              propylene glycol
# 22                                diethanolamine
# 96                              sodium chlorite
# 103                                  bisphenol A
# 109                        hydroxyethylcellulose
# 3                              antimony chloride
# 66                                       ethanol
# 60   tetrakis(hydroxymethyl) phosphonium sulfate
# 71                                      methanol
# 21                                glutaraldehyde
# 99                              ammonium sulfate
# 35                             ammonium chloride
# 14                               ethylene glycol
# 4                                     boric acid
# 44                 sodium tetraborate, anhydrous
# 7             2,2-dibromo-3-nitrilopropionamide
# 25               ethylene glycol monobutyl ether
# 72                                       acetone
# 6                                triethanolamine
# 100                           magnesium chloride
